# %% [markdown]
# # Web Scrapping

# %%
import pandas as pd

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# BeautifulSoup is a python library forpulling data out of HTML and XML files,It works with your favourite passer to provide ideamatic ways of navigating,Searching and Modifying the parse tree . It commenly saves programmers hours or days of works.

# %%
url = "https://www.flipkart.com/"

# %% [markdown]
# One of the most comman HTTP methods is GET. The GET method indicates that you're trying to get or retrive data from a specified resourse. To make a GET request , #Invoke requests.get()

# %%
r = requests.get(url)

# %%
print(r)
# Out:
# <Response [200]>

# %% [markdown]
# ## We will extract url of first page of mobile phones

# %%
url = "https://www.flipkart.com/search?q=mobile+phones+under+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY"

# %%
r = requests.get(url)

# %%
print(r)
# Out:
# <Response [200]>

# %%
Soup = BeautifulSoup(r.text,"lxml")

# %%
print(Soup) # will show the HTML code of first page
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# # Main code

# %%
# We have extracted all links
# now we get data of first page
Product_Name = []
Price = []
Description = []
Reviews = []
for i in range(2,5):
    url = "https://www.flipkart.com/search?q=mobile+phones+under+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY&page="+str(i)
    r = requests.get(url)
    Soup = BeautifulSoup(r.text,"lxml")
#np = Soup.find("a",class_="_1lktos").get("href")
#cnp = "https://www.flipkart.com/"+np
#print(cnp)
#go to div tag of phonr name and copyclass
    
    box = Soup.find("div",class_= "_1YokD2 _3Mn1Gg")
    names = box.find_all("div",class_= "_4rR01T")
    for i in names:
        name = i.text
        Product_Name.append(name)
    print(Product_Name) 
    
    Prices = box.find_all("div",class_= "_30jeq3 _1_WHN1")
    for i in Prices:
        name = i.text
        Price.append(name)
    print(Price)
    
    description = box.find_all("ul",class_= "_1xgFaf")
    for i in description:
        name = i.text
        Description.append(name)
    print(Description)
    
    reviews = box.find_all("div",class_= "_3LWZlK")
    for i in reviews:
        name = i.text
        Reviews.append(name)
    print(Reviews)
# Out:
# ['Xiaomi 12 Pro 5G (Couture Blue, 256 GB)', 'Apple iPhone XR (White, 64 GB) (Includes EarPods, Power Adapter)', 'vivo X90 (Asteroid Black, 256 GB)', 'IQOO 11 5G (Alpha, 256 GB)', 'realme X50 Pro (Moss Green, 256 GB)', 'IQOO 11 5G (Legend, 256 GB)', 'Xiaomi 11T Pro 5G Hyperphone (Celestial Magic, 256 GB)', 'OnePlus 9 Pro (Pine Green, 128 GB)', 'Apple iPhone 8 Plus (Gold, 64 GB)', 'vivo X60 (Midnight Black, 256 GB)', 'vivo X80 (Cosmic Black, 128 GB)', 'realme X50 Pro 5G (Rust Red, 256 GB)', 'Xiaomi 12 Pro 5G (Couture Blue, 256 GB)', 'Apple iPhone 8 Plus (Silver, 64 GB)', 'Apple iPhone 8 Plus (Space Grey, 64 GB)', 'SAMSUNG Galaxy S7 (Gold Platinum, 32 GB)', 'OPPO Reno7 Pro 5G (Startrails Blue, 256 GB)', 'OPPO Reno7 Pro 5G (Starlight Black, 256 GB)', 'OPPO Reno6 Pro 5G (Aurora, 256 GB)', 'OnePlus 11R 5G (Sonic Black, 256 GB)', 'OnePlus 11R 5G (Galactic Silver, 256 GB)', 'OnePlus 11R 5G (Galactic Silver, 128 GB)', 'Apple iPhone 12 (Black, 64 GB)', 'Apple iPhone 12 (Red, 64 GB)']
# ...

# %% [markdown]
# ## Converting the data to dataframe

# %%
print(len(Product_Name))
print(len(Price))
print(len(Description))
print(len(Reviews))
# Out:
# 72
# 72
# 72
# 70

# %%
import numpy as np
# Fill missing values in Description with NaN
Reviews += [np.nan] * 2

# %%
df = pd.DataFrame({"Product_Name": Product_Name,"Prices":Price,"Description":Description,"Reviews":Reviews})

# %%
df
# Out:
#                                          Product_Name   Prices  \
# 0             Xiaomi 12 Pro 5G (Couture Blue, 256 GB)  ₹49,990
# 1   Apple iPhone XR (White, 64 GB) (Includes EarPo...  ₹47,900
# 2                   vivo X90 (Asteroid Black, 256 GB)  ₹48,500
# 3                          IQOO 11 5G (Alpha, 256 GB)  ₹49,990
# 4                 realme X50 Pro (Moss Green, 256 GB)  ₹47,999
# ..                                                ...      ...
# 67                  Nothing Phone (2) (White, 256 GB)  ₹36,999
# 68                  Nothing Phone (2) (White, 512 GB)  ₹38,999
# 69                    Google Pixel 7a (Coral, 128 GB)  ₹39,999
# 70      SAMSUNG Galaxy S22 5G (Phantom Black, 128 GB)  ₹39,999
# 71      REDMI Note 13 Pro+ 5G (Fusion Purple, 512 GB)  ₹35,999
#
#                                           Description Reviews
# 0   8 GB RAM | 256 GB ROM17.09 cm (6.73 inch) Full...     4.1
# 1   64 GB ROM15.49 cm (6.1 inch) Display12MP Rear ...     4.6
# ...
